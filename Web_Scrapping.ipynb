# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
import os
import pandas as pd 
from io import StringIO
import numpy as np
from bs4 import BeautifulSoup

# %%
chromedriver_path = "chromedriver.exe"

# %%
# Inicializar el servicio de ChromeDriver
service = Service(chromedriver_path)
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://www.google.com")

# %%
URL = "https://www.exploit-db.com/"

# %%
driver.get(URL)

# %%
def get_html(url, selector, sleep_time=20):
    driver.get(url)
    time.sleep(sleep_time)
    element = driver.find_element(By.CSS_SELECTOR, selector) 
    return element.get_attribute("outerHTML")

# %%
html_content = get_html(URL, "#app")

# %%
soup = BeautifulSoup(html_content, "html.parser")

# %%
a_tags = soup.find_all("a", href=lambda href: href and "/exploits/" in href)

# %%
a_tags
# Out:
# [<a href="/exploits/52509">NetBT e-Fatura - Privilege Escalation</a>,
#  <a href="/exploits/52508">D-Link DIR-650IN - Authenticated Command Injection</a>,
#  <a href="/exploits/52506">React Server 19.2.0 - Remote Code Execution</a>,
#  <a href="/exploits/52505">RomM  4.4.0 -  XSS_CSRF Chain</a>,
#  <a href="/exploits/52504">Jumbo Website Manager  - Remote Code Execution</a>,
#  <a href="/exploits/52503">ZSH 5.9 - RCE</a>,
#  <a href="/exploits/52502">FortiWeb  8.0.2 - Remote Code Execution</a>,
#  <a href="/exploits/52501">7-Zip 24.00 - Directory Traversal</a>,
#  <a href="/exploits/52500">xibocms 3.3.4 - RCE</a>,
#  <a href="/exploits/52499">SQLite 3.50.1 - Heap Overflow</a>,
#  <a href="/exploits/52498">Microsoft MMC MSC EvilTwin - Local Admin Creation</a>,
#  <a href="/exploits/52497">Horilla v1.3 - RCE</a>,
#  <a href="/exploits/52496">is-localhost-ip 2.0.0 - SSRF</a>,
#  <a href="/exploits/52495">Fortinet FortiWeb v8.0.1 - Auth Bypass</a>,
#  <a href="/exploits/52494">Windows Kernel - Elevation of Privilege</a>]
